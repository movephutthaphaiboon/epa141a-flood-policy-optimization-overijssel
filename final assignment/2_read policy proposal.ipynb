# %% [markdown]
# # Import CSV

# %%
import pandas as pd

df = pd.read_csv("policy proposal/Overijssel policy proposal.csv", sep=';')

# %%
df
# Out:
#                                               Column1  \
# 0                                             Column1
# 1   HET GROTE BELEIDSRESULTATEN EXCELLETJE (Result...
# 2                                                 NaN
# 3                                                 NaN
# 4                              Rijkswaterstaat policy
# 5                                               RWS 1
# 6                                               RWS 2
# 7                                               RWS 3
# 8                                                 NaN
# 9                                   Policy Overijssel
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                             Policy
# 14                                                NaN
# 15                             Rijkswaterstaat policy
# ...
